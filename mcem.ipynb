# %%
from changepoint.mcem_sampler import *
import changepoint.init_functions as init
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext line_profiler
# %load_ext autoreload
# %autoreload 2
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Binary example

# %%
Yn = init.binary_data()

# %%
Thetas, Ps = mcem_sampler(Yn, model="binary", m=2, mcem=mcem_opt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1c4be2ec5aa4> in <module>()
# ----> 1 Thetas, Ps = mcem_sampler(Yn, model="binary", m=2, mcem=mcem_opt)
#
# /home/anh/projects/changepoint_model/changepoint/mcem_sampler.pyc in mcem_sampler(Yn, model, m, mcem, tol)
#      42
#      43         # E-step
# ---> 44         Sns = mcem.S_estep(N, Yn, Theta, P, model=model)
#      45
#      46         # M-step
#
# /home/anh/projects/changepoint_model/changepoint/mcem.pyc in S_estep(N, Yn, Theta, P, model, cond)
#       8
#       9     for N_ in range(N):
# ---> 10         Sn, F, F1 = cond.S_sampling(Yn, Theta, P, model)
#      11         Sns[:, N_] = Sn
#      12
#
# /home/anh/projects/changepoint_model/changepoint/full_conditionals.pyc in S_sampling(Yn, Theta, P, model)
#     137     m = len(Theta) - 1
#     138
# --> 139     F1, F0 = S_conditional(Yn, Theta, P, model=model)
#     140
#     141     F = np.zeros((n, m + 1))
#
# /home/anh/projects/changepoint_model/changepoint/full_conditionals.pyc in S_conditional(Yn, Theta, P, model)
#     121
#     122     for t in range(2, n + 1): # Forward
# --> 123         d_t = np.array([fy(t, k_, Yn, Theta, model) for k_ in range(1, m + 2)])
#     124         F1[t - 1] = ( F0[t - 2].dot(P) )
#     125         F0[t - 1] = F1[t - 1] * d_t
#
# /home/anh/projects/changepoint_model/changepoint/full_conditionals.pyc in fy(t, k, Yn, Theta, model)
#      96     '''
#      97     if model == "binary":
# ---> 98         return st.bernoulli.pmf(Yn[t-1], Theta[k-1])
#      99     elif model == "poisson":
#     100         return (Theta[k-1] ** Yn[t-1]) * np.exp(-Theta[k-1]) / np.math.factorial(Yn[t-1])
#
# /home/anh/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.pyc in pmf(self, k, *args, **kwds)
#    2746         place(output, (1-cond0) + np.isnan(k), self.badvalue)
#    2747         if any(cond):
# -> 2748             goodargs = argsreduce(cond, *((k,)+args))
#    2749             place(output, cond, np.clip(self._pmf(*goodargs), 0, 1))
#    2750         if output.ndim == 0:
#
# /home/anh/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.pyc in argsreduce(cond, *args)
#     572         newargs = [newargs, ]
#     573     expand_arr = (cond == cond)
# --> 574     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#     575
#     576
#
# /home/anh/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in extract(condition, arr)
#    1444
#    1445     """
# -> 1446     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#    1447
#    1448
#
# /home/anh/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in ravel(a, order)
#    1375
#    1376     """
# -> 1377     return asarray(a).ravel(order)
#    1378
#    1379
#
# /home/anh/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:

# %%
plt.plot(Thetas.T);

# %% [markdown]
# ## Poisson example

# %%
Yn_poisson = init.poisson_data()

# %%
Thetas, Theta, P = mcem_sampler(Yn_poisson, model="poisson", m=1, mcem=mcem_opt)

# %%
plt.plot(Thetas.T);
print Thetas[:, 99]
# Out:
# [ 3.1251153   0.92424452]

# %%
Thetas, Theta, P = mcem_sampler(Yn_poisson, model="poisson", m=2, mcem=mcem_opt)

# %%
plt.plot(Thetas.T);
Thetas[:, 99]
# Out:
# array([ 4.        ,  3.10211813,  0.9255741 ])

# %%
P
# Out:
# array([[ 0.        ,  1.        ,  0.        ],
#        [ 0.        ,  0.97416911,  0.02583089],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
Thetas, Theta, P = mcem_sampler(Yn_poisson, model="poisson", m=2, mcem=mcem)

# %%
plt.plot(Thetas.T);
Thetas[:, 99]
# Out:
# array([ 4.        ,  5.        ,  1.65454545])
